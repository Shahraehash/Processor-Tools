# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Volumes/researchFiles/amz_files/A_TBvsHealthy-synthetic.csv')

# %%
df
# Out:
#       Rv3881     Rv0934   HSPX     Ag85b    Rv1860  CFP10      Rv1926c   \
# 0           14       14      292       21       21      259          47
# 1          915       85     2333      183       59     1089        2376
# 2           40       21       30       79       18       50          23
# 3         5363      232       23      102       47       75          57
# 4          678       85     2333     8623    10929      130          63
# ..         ...      ...      ...      ...      ...      ...         ...
# 119         29      147       40       24      153      163         153
# 120        102      399       47       78       64      163         138
# 121       6933       33       41      521       26       97          63
# 122         17       11       32       29      100       20          25
# 123        178      242      358     4385     1200      163          63
#
#       Rv1984    Rv3841   Rv2875   ...   Rv2220    Rv2032    Rv3873    Rv0054   \
# ...
